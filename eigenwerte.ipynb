# %%
import numpy as np

# %%
F=np.matrix([[1,2,3],[2,-4,-2],[3,-2,1]])
print(F)

# %%
np.linalg.eig(A)

# %% [markdown]
# Die Eigenwerte sind in der Zeile des Arrays zu finden. Die Spalten der Matrix sind die normierten Eigenvektoren. Leider sind die normierten EVen gar nich so leicht mit ihren Ergebnissen zu vergleichen. Die erste Spalte ist ein Vielfaches von (1 -2 -1)^T und die Zweite von (1,0,1)^T un die dritte ?
